# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## Transformer中所要用到的前馈神经网络

# %%
class FeedForwardNeuralNetwork(nn.Module):
    def __init__(self):
        super(FeedForwardNeuralNetwork, self).__init__()
        # 输入层到第一个隐藏层
        self.fc1 = nn.Linear(512, 2048)
        # 第二个隐藏层到输出层
        self.fc2 = nn.Linear(2048, 512)
    def forward(self, x):
        out = self.fc1(x)
        out = torch.relu(out)
        out = self.fc2(out)
        return out

# %%
model = FeedForwardNeuralNetwork()
print(model)
# Out:
# FeedForwardNeuralNetwork(
#   (fc1): Linear(in_features=512, out_features=2048, bias=True)
#   (fc2): Linear(in_features=2048, out_features=512, bias=True)
# )

# %% [markdown]
# ### 神经网络测试

# %%
x = torch.randn(10, 512)
y = torch.randn(10, 512)

# 使用 SGD 优化器
optimizer = optim.SGD(model.parameters(), lr=0.01)
# 均方误差损失
criterion = nn.MSELoss()

for epoch in range(1000):
    model.train()  # 设置模型为训练模式
    optimizer.zero_grad()  # 清除梯度
    output = model(x)  # 前向传播
    loss = criterion(output, y)  # 计算损失
    loss.backward()  # 反向传播
    optimizer.step()  # 更新权重
    if (epoch + 1) % 50 == 0:  # 每 10 轮输出一次损失
        print(f'Epoch [{epoch + 1}/100], Loss: {loss.item():.4f}')
# Out:
# Epoch [50/100], Loss: 0.8952
# Epoch [100/100], Loss: 0.7634
# Epoch [150/100], Loss: 0.6563
# Epoch [200/100], Loss: 0.5653
# Epoch [250/100], Loss: 0.4858
# Epoch [300/100], Loss: 0.4154
# Epoch [350/100], Loss: 0.3526
# Epoch [400/100], Loss: 0.2967
# Epoch [450/100], Loss: 0.2472
# Epoch [500/100], Loss: 0.2039
# Epoch [550/100], Loss: 0.1664
# Epoch [600/100], Loss: 0.1345
# Epoch [650/100], Loss: 0.1076
# Epoch [700/100], Loss: 0.0854
# Epoch [750/100], Loss: 0.0672
# Epoch [800/100], Loss: 0.0524
# Epoch [850/100], Loss: 0.0407
# Epoch [900/100], Loss: 0.0314
# Epoch [950/100], Loss: 0.0241
# Epoch [1000/100], Loss: 0.0185
